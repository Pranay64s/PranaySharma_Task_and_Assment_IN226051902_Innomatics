# %%
# Problem 1

def validate_recharge(amount, valid_plans):
    if amount < 50:
        return "Recharge amount must be at least ₹50."
    elif amount not in valid_plans:
        return "Invalid plan selected."
    else:
        return "Recharge Successful"

valid_plans = [199, 299, 399, 599]

while True:
    amount = int(input("Enter recharge amount: "))
    result = validate_recharge(amount, valid_plans)
    print(result)

    if result == "Recharge Successful":
        break
    else:
        print("Please try again.\n")
# Out:
# Enter recharge amount: 200
# Invalid plan selected.
# Please try again.
#
# Enter recharge amount: 299
# Recharge Successful

# %%
# Problem 2

def check_inventory(products):
    for product, stock in products.items():
        if stock < 15:
            print(product, ": Reorder Alert")
        else:
            print(product, ": Stock OK")

inventory = {
    "Laptop": 10,
    "Mouse": 25,
    "Keyboard": 12,
    "Monitor": 18
}

check_inventory(inventory)
# Out:
# Laptop : Reorder Alert
# Mouse : Stock OK
# Keyboard : Reorder Alert
# Monitor : Stock OK

# %%
# Problem 3

def process_result(marks):
    if not marks:
        return "No marks provided."

    total_marks = 0
    for mark in marks:
        total_marks += mark

    average = total_marks / len(marks)

    if average >= 50:
        return f"Pass (Average: {average:.2f})"
    else:
        return f"Fail (Average: {average:.2f})"

student_1 = [55, 60, 45, 70]
student_2 = [40, 35, 50, 45]

print(f"Student 1: {process_result(student_1)}")
print(f"Student 2: {process_result(student_2)}")
# Out:
# Student 1: Pass (Average: 57.50)
# Student 2: Fail (Average: 42.50)

# %%
# Problem 4

def calculate_fare(distance, peak):
    base_fare = 50
    per_km = 12

    fare = base_fare + (distance * per_km)

    if peak.lower() == "yes":
        fare += fare * 0.25

    return fare

while True:
    distance = float(input("Enter distance in km: "))
    peak = input("Is it peak hour? (yes/no): ")

    total_fare = calculate_fare(distance, peak)
    print("Total Fare: ₹", total_fare)

    retry = input("Do you want to calculate again? (yes/no): ")
    if retry.lower() != "yes":
        break
# Out:
# Enter distance in km: 7
# Is it peak hour? (yes/no): no
# Total Fare: ₹ 134.0
# Do you want to calculate again? (yes/no): yes
# Enter distance in km: 7
# Is it peak hour? (yes/no): yes
# Total Fare: ₹ 167.5

# %%
# Problem 5

def check_eligibility(attendance):
    present_days = 0

    for day in attendance:
        if day == "P":
            present_days += 1

    percentage = (present_days / len(attendance)) * 100

    if percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"

attendance_list = ["P", "P", "A", "P", "P", "A", "P", "P"]
status = check_eligibility(attendance_list)
print("Attendance Status:", status)
# Out:
# Attendance Status: Eligible

# %%
# Problem 6

def check_password_strength(password):
    if len(password) < 8:
        return "Weak: Password must be at least 8 characters long."

    has_digit = False
    has_special = False
    valid_specials = "@#$"

    for char in password:
        if char.isdigit():
            has_digit = True
        elif char in valid_specials:
            has_special = True

    if not has_digit:
        return "Weak: Password must contain at least one digit."
    if not has_special:
        return "Weak: Password must contain at least one special character (@, #, or $)."

    return "Strong: Password is secure."

print(check_password_strength("user123"))
print(check_password_strength("Security#"))
print(check_password_strength("Pass@word1"))
# Out:
# Weak: Password must be at least 8 characters long.
# Weak: Password must contain at least one digit.
# Strong: Password is secure.
